# %%
from dotenv import load_dotenv
from openrouter import OpenRouter
import os

# %%
load_dotenv(override=True)

open_router_api_key = os.getenv('OPEN_ROUTER_API_KEY')
model = os.getenv('MODEL', 'openai/gpt-oss-20b:free')

if open_router_api_key:
    print(f"Open Router API Key exists and begins {open_router_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")

print(f"Using model: {model}")
# Out:
# Open Router API Key exists and begins sk-or-v1
# Using model: openai/gpt-oss-20b:free

# %%
from IPython.display import Markdown, display

question = "What is the meaning of life?"

response = OpenRouter(api_key=open_router_api_key).chat.send(
    model=model,
    messages=[
        {"role": "user", "content": question}
    ],
)

answer = response.choices[0].message.content
display(Markdown(answer))
# Out:
# The question “What is the meaning of life?” has occupied philosophers, theologians, scientists, artists, and ordinary people for millennia. Because it touches on the deepest aspects of human existence—our purpose, our values, our place in the cosmos—there is no single, universally accepted answer. Instead, most thinkers agree that the meaning of life is something we create, discover, or negotiate rather than something that is handed down to us in a finished form.
#
# ---
#
# ## 1. A Few Broad Perspectives
#
# | Perspective | Core Idea | Typical Questions It Raises |
# |-------------|-----------|-----------------------------|
# | **Religious / Spiritual** | Life’s purpose is defined by a divine plan, moral law, or spiritual evolution. | “What does my faith say about my purpose?” “How do I live in accordance with a higher will?” |
# | **Philosophical / Existential** | Meaning is not pre‑given; we must give it ourselves through choices, authenticity, and confronting absurdity. | “What values do I choose to live by?” “How do I confront the inevitability of death?” |
# | **Humanistic / Psychological** | Meaning arises from relationships, personal growth, and contributing to others’ well‑being. | “What relationships bring me joy?” “How can I help others?” |
# | **Scientific / Evolutionary** | Life’s “meaning” is a byproduct of evolution: survival, reproduction, and the propagation of genes. | “Why do we feel compelled to create?” “What drives curiosity?” |
# | **Narrative / Storytelling** | We construct meaning by weaving our experiences into a coherent story that gives our life direction. | “What narrative do I want to tell about my life?” “How do my past, present, and future connect?” |
#
# ---
#
# ## 2. Common Themes That Cross These Views
#
# 1. **Connection** – Relationships with family, friends, community, or even nature give life texture and purpose.
# 2. **Growth** – Learning, skill‑building, and self‑improvement provide a sense of progress.
# 3. **Contribution** – Helping others, creating art, or advancing knowledge can feel like leaving a legacy.
# 4. **Authenticity** – Living in alignment with one’s values and passions reduces inner conflict.
# 5. **Joy & Curiosity** – Experiencing wonder, pleasure, and the thrill of discovery keeps life vibrant.
#
# ---
#
# ## 3. How to Explore Your Own Meaning
#
# | Step | What to Do | Why It Helps |
# |------|------------|--------------|
# | **Reflect** | Keep a journal, meditate, or simply sit with your thoughts. | Clarifies what truly matters to you. |
# | **Experiment** | Try new hobbies, volunteer, travel, or study different philosophies. | Exposes you to possibilities you hadn’t considered. |
# | **Set Goals** | Define short‑term and long‑term objectives that align with your values. | Gives concrete direction and a sense of accomplishment. |
# | **Seek Community** | Join groups that share your interests or values. | Provides support, feedback, and shared meaning. |
# | **Revisit Regularly** | Reassess your goals and values every few months or years. | Life changes; meaning can evolve. |
#
# ---
#
# ## 4. A Few Thought‑Provoking Quotes
#
# - **Albert Camus** – “The absurd is the essential concept of the human condition. The absurd is the confrontation between the human desire for meaning and the silent, indifferent universe.”
# - **Viktor Frankl** – “When we are no longer able to change a situation, we are challenged to change ourselves.”
# - **Ralph Waldo Emerson** – “To be yourself in a world that is constantly trying to make you something else is the greatest accomplishment.”
#
# ---
#
# ## 5. Bottom Line
#
# - **There is no single “correct” answer.** The meaning of life is a personal, evolving project.
# - **You can create meaning** by aligning your actions with what feels authentic, valuable, and joyful to you.
# - **It’s a journey, not a destination.** The process of seeking, questioning, and living deliberately often becomes its own reward.
#
# So, while the universe may not hand you a ready‑made purpose, you have the tools to craft a life that feels meaningful to you. The question itself invites you to explore, experiment, and ultimately live a life that resonates with your deepest self.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

messages = [{"role": "user", "content": message}]
response = OpenRouter(api_key=open_router_api_key).chat.send(
    model=model,
    messages=messages,
)

display(Markdown(response.choices[0].message.content))
# Out:
# **Correct** – The answer provides a balanced, well‑structured overview of the many philosophical, religious, psychological, scientific, and cultural perspectives on the meaning of life. It acknowledges that there is no single universally accepted answer and instead presents a range of common themes, practical steps for personal exploration, and thought‑provoking quotes. This aligns with the nature of the question, which is inherently open‑ended and subjective.
